# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcoLe3/LangGraph_Tutorial/blob/main/exercise_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import Dict, TypedDict
from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):
  message: str

def compliment_node(state: AgentState) -> AgentState:
  """compliments on learning langgraph"""
  state["message"] = "Hi " + state["message"] + " you're doing good learning langgraph"
  return state

graph = StateGraph(AgentState)
graph.add_node("complimenter", compliment_node)

graph.set_entry_point("complimenter")
graph.set_finish_point("complimenter")

app = graph.compile()

# %%
app.invoke({"message": "Bob"})
# Out:
# {'message': "Hi Bob you're doing good learning langgraph"}
